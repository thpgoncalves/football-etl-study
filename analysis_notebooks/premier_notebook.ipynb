# %%
import sys
sys.path.append("../src")
from functions import read_csv
import pandas as pd

# %%
premier_2024 = read_csv('premier_2024')
premier_2024
# Out:
#     Div        Date   Time        HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  16/08/2024  20:00      Man United       Fulham     1     0   H     0
# 1    E0  17/08/2024  12:30         Ipswich    Liverpool     0     2   A     0
# 2    E0  17/08/2024  15:00         Arsenal       Wolves     2     0   H     1
# 3    E0  17/08/2024  15:00         Everton     Brighton     0     3   A     0
# 4    E0  17/08/2024  15:00       Newcastle  Southampton     1     0   H     1
# ..   ..         ...    ...             ...          ...   ...   ...  ..   ...
# 224  E0  25/01/2025  17:30        Man City      Chelsea     3     1   H     1
# 225  E0  26/01/2025  14:00  Crystal Palace    Brentford     1     2   A     0
# 226  E0  26/01/2025  14:00       Tottenham    Leicester     1     2   A     1
# 227  E0  26/01/2025  16:30     Aston Villa     West Ham     1     1   D     1
# 228  E0  26/01/2025  19:00          Fulham   Man United     0     1   A     0
#
# ...
