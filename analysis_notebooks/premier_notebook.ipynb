# %%
import sys
sys.path.append("../src")
from functions import *
import pandas as pd

# %%
year = 2023
selected_columns = ["Div", "Date", "HomeTeam", "AwayTeam", "FTHG", "FTAG", 
                    "FTR", "HTHG", "HTAG", "HTR", "Referee", "HS", "AS", 
                    "HST", "AST", "HF", "AF", "HC", "AC", "HY", "AY", "HR", "AR"]
dfs = []

while year > 2009:
    temp = read_csv(f'premier_{year}')
    temp = temp[selected_columns]
    dfs.append(temp)
    year -= 1

df_premier = pd.concat(dfs, ignore_index=True)
# df_premier = add_year(df_premier, 'Date')
# df_premier = calculate_points(df_premier)
# df_premier_agg = calculate_goals_statistics(df_premier)
# df_premier_agg.sort_values(by='goal_diff', ascending=False)

table2022 = create_classification_table(df_premier, 2021)
table2022
# Out:
#                 Team  Total Points  Wins  Draws  Loses  Goals Diff  Goals For  \
# 12          Man City         110.0  36.0      2    6.0        81.0      113.0
# 5            Chelsea          83.0  24.0     11    7.0        38.0       70.0
# 11         Liverpool          77.0  23.0      8   10.0        43.0       81.0
# 0            Arsenal          76.0  23.0      7   11.0        28.0       71.0
# 13        Man United          75.0  21.0     12    8.0        25.0       72.0
# 21          West Ham          73.0  22.0      7   12.0        22.0       73.0
# 18         Tottenham          66.0  20.0      6   14.0        14.0       64.0
# 10         Leicester          62.0  18.0      8   14.0         7.0       70.0
# 3           Brighton          52.0  12.0     16   12.0         0.0       39.0
# 9              Leeds          52.0  14.0     10   16.0       -10.0       50.0
# 1        Aston Villa          51.0  15.0      6   21.0        -9.0       51.0
# ...
